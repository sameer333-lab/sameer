# %% [markdown]
# <a href="https://colab.research.google.com/github/sameer333-lab/sameer/blob/main/Sameer_Gawande_Financial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\sameer\Downloads/Financial Analytics data.csv')

# %%
df
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0        1   Reliance Inds.        583436.72           99810.00         NaN
# 1        2              TCS        563709.84           30904.00         NaN
# 2        3        HDFC Bank        482953.59           20581.27         NaN
# 3        4              ITC        320985.27            9772.02         NaN
# 4        5          H D F C        289497.37           16840.51         NaN
# ..     ...              ...              ...                ...         ...
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN
#
# [488 rows x 5 columns]

# %%
df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              488 non-null    int64
#  1   Name               488 non-null    object
#  2   Mar Cap - Crore    479 non-null    float64
#  3   Sales Qtr - Crore  365 non-null    float64
#  4   Unnamed: 4         94 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 19.2+ KB

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore   Unnamed: 4
# count  488.000000       479.000000         365.000000    94.000000
# mean   251.508197     28043.857119        4395.976849  1523.870106
# std    145.884078     59464.615831       11092.206185  1800.008836
# min      1.000000      3017.070000          47.240000     0.000000
# 25%    122.750000      4843.575000         593.740000   407.167500
# 50%    252.500000      9885.050000        1278.300000   702.325000
# 75%    378.250000     23549.900000        2840.750000  2234.815000
# max    500.000000    583436.720000      110666.930000  7757.060000

# %%
df.tail()
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN

# %%
# Drop the unnamed column
df = df.drop(columns=['Unnamed: 4'])

# %%
df
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0        1   Reliance Inds.        583436.72           99810.00
# 1        2              TCS        563709.84           30904.00
# 2        3        HDFC Bank        482953.59           20581.27
# 3        4              ITC        320985.27            9772.02
# 4        5          H D F C        289497.37           16840.51
# ..     ...              ...              ...                ...
# 483    496  Lak. Vilas Bank          3029.57             790.17
# 484    497            NOCIL          3026.26             249.27
# 485    498    Orient Cement          3024.32             511.53
# 486    499  Natl.Fertilizer          3017.07            2840.75
# 487    500        L T Foods              NaN                NaN
#
# [488 rows x 4 columns]

# %%
print(df.head())
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %% [markdown]
# # calculate key matrics

# %%
mean_mar_cap = df['Mar Cap - Crore'].mean()
median_mar_cap = df['Mar Cap - Crore'].median()
std_mar_cap = df['Mar Cap - Crore'].std()

# %%
mean_mar_cap
# Out:
# 28043.857118997912

# %%
median_mar_cap
# Out:
# 9885.05

# %%
std_mar_cap
# Out:
# 59464.61583102017

# %%
std_mar_cap/100
# Out:
# 594.6461583102017

# %%
median_mar_cap/100
# Out:
# 98.8505

# %%
mean_mar_cap/100
# Out:
# 280.43857118997914

# %%
print(f"Market Capitalization - Mean: {mean_mar_cap}, Median: {median_mar_cap}, Std Dev: {std_mar_cap}")
# Out:
# Market Capitalization - Mean: 28043.857118997912, Median: 9885.05, Std Dev: 59464.61583102017

# %%
mean_sales_qtr = df['Sales Qtr - Crore'].mean()
median_sales_qtr = df['Sales Qtr - Crore'].median()
std_sales_qtr = df['Sales Qtr - Crore'].std()

# %%
mean_sales_qtr
# Out:
# 4395.976849315068

# %%
std_sales_qtr
# Out:
# 11092.2061854928

# %%
median_sales_qtr
# Out:
# 1278.3

# %%
print(f"Quarterly Sales - Mean: {mean_sales_qtr}, Median: {median_sales_qtr}, Std Dev: {std_sales_qtr}")
# Out:
# Quarterly Sales - Mean: 4395.976849315068, Median: 1278.3, Std Dev: 11092.2061854928

# %% [markdown]
# # Visualization
# Visualize the relationship between Market Capitalization and Quarterly Sales

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mar Cap - Crore', y='Sales Qtr - Crore', data=df)
plt.title('Market Capitalization vs Quarterly Sales')
plt.xlabel('Market Capitalization (Crores)')
plt.ylabel('Quarterly Sales (Crores)')
plt.show()

# %% [markdown]
# # Histogram of Market Capitalization

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Mar Cap - Crore'], bins=30, kde=True)
plt.title('Distribution of Market Capitalization')
plt.xlabel('Market Capitalization (Crores)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Histogram of Quarterly Sales

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Sales Qtr - Crore'], bins=30, kde=True)
plt.title('Distribution of Quarterly Sales')
plt.xlabel('Quarterly Sales (Crores)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #  Boxplot of Market Capitalization

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Mar Cap - Crore'])
plt.title('Boxplot of Market Capitalization')
plt.xlabel('Market Capitalization (Crores)')
plt.show()

# %% [markdown]
# # Boxplot of Quarterly Sales

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Sales Qtr - Crore'])
plt.title('Boxplot of Quarterly Sales')
plt.xlabel('Quarterly Sales (Crores)')
plt.show()

# %% [markdown]
# # Pair plot

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(df, diag_kind='kde')
plt.suptitle('Pair Plot', y=1.02)
plt.show()
# Out:
# D:\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
